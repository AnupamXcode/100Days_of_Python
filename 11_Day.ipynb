# %%
# Create a function named hello() that prints:
def hello():
  print("Hello World")
hello()
# Out:
# Hello World

# %%
# Create a function square(n) that prints the square of a number.
def square(n):
  sq=n*n
  print(sq)
square(5)
# Out:
# 25

# %%
# Create a function add(a, b) that returns the sum of two numbers.
def add(a, b):
  return a+b;
add(2,3)
# Out:
# 5

# %%
# Create a function check_even(n) that:
def check_even(n):
  if n%2==0:
    print("Even")
  else :
    print("Odd")
check_even(4)
# Out:
# Even
